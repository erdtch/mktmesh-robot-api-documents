# %%
# %matplotlib notebook
import pandas as pd
from io import StringIO
import urllib
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import ticker as ticker
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates

# read text to dataframe
df = pd.read_csv('candlestick.csv', names=['time', 'open', 'high', 'low', 'close', 'volume', 'oi'], parse_dates=True)
df.tail(10)
# Out:
#                     time   open   high    low  close    volume  oi
# 721  2018-08-03 07:00:00  51.75  52.25  51.50  51.75  41694700   0
# 722  2018-08-06 07:00:00  52.00  52.25  51.25  51.50  39754800   0
# 723  2018-08-07 07:00:00  51.75  52.50  51.25  52.25  58994400   0
# 724  2018-08-08 07:00:00  52.25  53.00  52.25  53.00  82988200   0
# 725  2018-08-09 07:00:00  52.50  53.00  52.50  52.50  50597000   0
# 726  2018-08-10 07:00:00  52.25  52.75  51.75  51.75  47011600   0
# 727  2018-08-14 07:00:00  51.50  52.00  51.00  51.75  58340400   0
# 728  2018-08-15 07:00:00  51.50  51.75  50.75  51.00  52610500   0
# 729  2018-08-16 07:00:00  50.50  50.75  49.50  50.50  95573700   0
# 730  2018-08-17 07:00:00  51.00  52.00  51.00  51.50  70988500   0

# %%
# Converting date to pandas datetime format
df['time'] = pd.to_datetime(df['time'])
df["time"] = df["time"].apply(mdates.date2num)
df.tail(10)
# Out:
#               time   open   high    low  close    volume  oi
# 721  736909.291667  51.75  52.25  51.50  51.75  41694700   0
# 722  736912.291667  52.00  52.25  51.25  51.50  39754800   0
# 723  736913.291667  51.75  52.50  51.25  52.25  58994400   0
# 724  736914.291667  52.25  53.00  52.25  53.00  82988200   0
# 725  736915.291667  52.50  53.00  52.50  52.50  50597000   0
# 726  736916.291667  52.25  52.75  51.75  51.75  47011600   0
# 727  736920.291667  51.50  52.00  51.00  51.75  58340400   0
# 728  736921.291667  51.50  51.75  50.75  51.00  52610500   0
# 729  736922.291667  50.50  50.75  49.50  50.50  95573700   0
# 730  736923.291667  51.00  52.00  51.00  51.50  70988500   0

# %%
ohlc = df[['time', 'open', 'high', 'low','close']].tail(20).copy()
f1, ax = plt.subplots()
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(ticker.MaxNLocator(6))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
